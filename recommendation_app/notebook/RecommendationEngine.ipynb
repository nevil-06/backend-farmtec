# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from joblib import dump

# %%
df = pd.read_csv('keyur_dataset_converted.csv')
display(df)
# Out:
#                        Region  Population_Density Avg_Temperature  \
# 0                     Alberta                 6.4          -2.5°C
# 1                     Alberta                 6.4          -2.5°C
# 2                     Alberta                 6.4          -2.5°C
# 3                     Alberta                 6.4          -2.5°C
# 4                     Alberta                 6.4          -2.5°C
# 5            British Columbia                 5.0          12.5°C
# 6            British Columbia                 5.0          12.5°C
# 7            British Columbia                 5.0          12.5°C
# 8            British Columbia                 5.0          12.5°C
# 9            British Columbia                 5.0          12.5°C
# 10                   Manitoba                 5.7          -5.5°C
# 11                   Manitoba                 5.7          -5.5°C
# 12                   Manitoba                 5.7          -5.5°C
# 13                   Manitoba                 5.7          -5.5°C
# 14                   Manitoba                 5.7          -5.5°C
# 15                    Ontario                14.7          10.0°C
# 16                    Ontario                14.7          10.0°C
# 17                    Ontario                14.7          10.0°C
# 18                    Ontario                14.7          10.0°C
# 19                    Ontario                14.7          10.0°C
# 20                     Quebec                 6.2           6.5°C
# 21                     Quebec                 6.2           6.5°C
# 22                     Quebec                 6.2           6.5°C
# 23                     Quebec                 6.2           6.5°C
# 24                     Quebec                 6.2           6.5°C
# 25               Saskatchewan                 2.0          -5.0°C
# 26               Saskatchewan                 2.0          -5.0°C
# 27               Saskatchewan                 2.0          -5.0°C
# 28               Saskatchewan                 2.0          -5.0°C
# 29               Saskatchewan                 2.0          -5.0°C
# 30  Newfoundland and Labrador                 1.4           1.5°C
# 31  Newfoundland and Labrador                 1.4           1.5°C
# 32  Newfoundland and Labrador                 1.4           1.5°C
# 33  Newfoundland and Labrador                 1.4           1.5°C
# 34  Newfoundland and Labrador                 1.4           1.5°C
# 35  Newfoundland and Labrador                 1.4           1.5°C
# 36                Nova Scotia                17.4           8.5°C
# 37                Nova Scotia                17.4           8.5°C
# 38                Nova Scotia                17.4           8.5°C
# 39                Nova Scotia                17.4           8.5°C
# 40                Nova Scotia                17.4           8.5°C
# 41              New Brunswick                10.6           6.8°C
# 42              New Brunswick                10.6           6.8°C
# 43              New Brunswick                10.6           6.8°C
# 44              New Brunswick                10.6           6.8°C
# 45              New Brunswick                10.6           6.8°C
# 46       Prince Edward Island                25.1           8.1°C
# 47       Prince Edward Island                25.1           8.1°C
# 48       Prince Edward Island                25.1           8.1°C
# 49       Prince Edward Island                25.1           8.1°C
# 50       Prince Edward Island                25.1           8.1°C
# 51               Saskatchewan                 2.0          -5.0°C
# 52               Saskatchewan                 2.0          -5.0°C
# 53               Saskatchewan                 2.0          -5.0°C
# 54               Saskatchewan                 2.0          -5.0°C
# 55               Saskatchewan                 2.0          -5.0°C
#
#     Sunshine_Hours  Soil_Type Agricultural_Practices            Crop  \
# 0             2300  Chernozem          Mixed farming          Canola
# 1             2300  Chernozem          Mixed farming           Wheat
# 2             2300  Chernozem          Mixed farming          Barley
# 3             2300  Chernozem          Mixed farming        Potatoes
# 4             2300  Chernozem          Mixed farming            Peas
# 5             1800     Podzol          Fruit farming     Blueberries
# 6             1800     Podzol          Fruit farming          Apples
# 7             1800     Podzol          Fruit farming        Cherries
# 8             1800     Podzol          Fruit farming          Grapes
# 9             1800     Podzol          Fruit farming         Peaches
# 10            2100  Chernozem          Grain farming           Wheat
# 11            2100  Chernozem          Grain farming          Canola
# 12            2100  Chernozem          Grain farming          Barley
# 13            2100  Chernozem          Grain farming        Soybeans
# 14            2100  Chernozem          Grain farming            Corn
# 15            2200    Luvisol          Mixed farming            Corn
# 16            2200    Luvisol          Mixed farming        Soybeans
# 17            2200    Luvisol          Mixed farming           Wheat
# 18            2200    Luvisol          Mixed farming          Barley
# 19            2200    Luvisol          Mixed farming        Potatoes
# 20            2000     Podzol          Dairy farming  Dairy Products
# 21            2000     Podzol          Dairy farming     Maple Syrup
# 22            2000     Podzol          Dairy farming          Apples
# 23            2000     Podzol          Dairy farming        Potatoes
# 24            2000     Podzol          Dairy farming     Blueberries
# 25            2200  Chernozem          Grain farming           Wheat
# 26            2200  Chernozem          Grain farming          Canola
# 27            2200  Chernozem          Grain farming          Barley
# 28            2200  Chernozem          Grain farming         Lentils
# 29            2200  Chernozem          Grain farming            Peas
# 30            1600     Podzol                Fishing             Cod
# 31            1600     Podzol                Fishing             Cod
# 32            1600     Podzol                Fishing       Snow Crab
# 33            1600     Podzol                Fishing         Lobster
# 34            1600     Podzol                Fishing         Capelin
# 35            1600     Podzol                Fishing         Mussels
# 36            2100     Podzol          Fruit farming          Apples
# 37            2100     Podzol          Fruit farming     Blueberries
# 38            2100     Podzol          Fruit farming    Strawberries
# 39            2100     Podzol          Fruit farming     Cranberries
# 40            2100     Podzol          Fruit farming          Grapes
# 41            2000     Podzol          Dairy farming  Dairy Products
# 42            2000     Podzol          Dairy farming        Potatoes
# 43            2000     Podzol          Dairy farming     Blueberries
# 44            2000     Podzol          Dairy farming          Apples
# 45            2000     Podzol          Dairy farming     Maple Syrup
# 46            2100    Luvisol         Potato farming        Potatoes
# 47            2100    Luvisol         Potato farming          Barley
# 48            2100    Luvisol         Potato farming           Wheat
# 49            2100    Luvisol         Potato farming     Blueberries
# 50            2100    Luvisol         Potato farming    Strawberries
# 51            2200  Chernozem          Grain farming           Wheat
# 52            2200  Chernozem          Grain farming          Canola
# 53            2200  Chernozem          Grain farming          Barley
# 54            2200  Chernozem          Grain farming         Lentils
# 55            2200  Chernozem          Grain farming            Peas
#
#     Quantity_Produced (in million kg) Market_Price (per kg)
# 0                                 7.2                 $0.35
# 1                                12.5                 $0.20
# 2                                 8.3                 $0.25
# 3                                 2.1                 $0.50
# 4                                 3.8                 $0.40
# 5                                 0.9                 $1.50
# 6                                 1.5                 $0.80
# 7                                 0.6                 $2.00
# 8                                 0.8                 $1.20
# 9                                 0.4                 $1.80
# 10                               10.8                 $0.20
# 11                                6.5                 $0.35
# 12                                5.2                 $0.25
# 13                                3.7                 $0.45
# 14                                2.9                 $0.30
# 15                                9.2                 $0.30
# 16                                7.5                 $0.45
# 17                               11.3                 $0.20
# 18                                6.8                 $0.25
# 19                                1.9                 $0.50
# 20                                9.7                 $1.80
# 21                                0.8                 $3.50
# 22                                1.2                 $0.80
# 23                                2.5                 $0.50
# 24                                0.6                 $1.50
# 25                               14.5                 $0.20
# 26                               10.2                 $0.35
# 27                                7.8                 $0.25
# 28                                3.4                 $0.60
# 29                                4.2                 $0.40
# 30                               23.8                 $3.00
# 31                               23.8                 $3.00
# 32                               10.5                 $5.50
# 33                                8.7                 $9.00
# 34                                4.2                 $1.20
# 35                                3.8                 $2.50
# 36                                0.8                 $0.80
# 37                                1.2                 $1.50
# 38                                0.6                 $2.20
# 39                                0.9                 $1.80
# 40                                0.4                 $1.20
# 41                                4.5                 $1.80
# 42                                1.3                 $0.50
# 43                                0.7                 $1.50
# 44                                0.5                 $0.80
# 45                                0.3                 $3.50
# 46                                1.8                 $0.50
# 47                                0.6                 $0.25
# 48                                0.4                 $0.20
# 49                                0.3                 $1.50
# 50                                0.2                 $2.20
# 51                               14.5                 $0.20
# 52                               10.2                 $0.35
# 53                                7.8                 $0.25
# 54                                3.4                 $0.60
# 55                                4.2                 $0.40

# %%
le_region = LabelEncoder()
le_soil = LabelEncoder()
le_crop = LabelEncoder()
le_agricultural_practices = LabelEncoder()

# %%
df['Region'] = le_region.fit_transform(df['Region'])
df['Soil_Type'] = le_soil.fit_transform(df['Soil_Type'])
df['Crop'] = le_crop.fit_transform(df['Crop'])
df['Agricultural_Practices'] = le_agricultural_practices.fit_transform(df['Agricultural_Practices'])

# %%
# Accessing the encoded values and their corresponding classes
encoded_classes_region = le_region.classes_
print("Encoded Classes:", encoded_classes_region)

# Printing encoded values for each class
for cls, encoded_value in zip(encoded_classes_region, range(len(encoded_classes_region))):
    print(f"Class: {cls} - Encoded Value: {encoded_value}")
# Out:
# Encoded Classes: ['Alberta' 'British Columbia' 'Manitoba' 'New Brunswick'
#  'Newfoundland and Labrador' 'Nova Scotia' 'Ontario'
#  'Prince Edward Island' 'Quebec' 'Saskatchewan']
# Class: Alberta - Encoded Value: 0
# Class: British Columbia - Encoded Value: 1
# Class: Manitoba - Encoded Value: 2
# Class: New Brunswick - Encoded Value: 3
# Class: Newfoundland and Labrador - Encoded Value: 4
# Class: Nova Scotia - Encoded Value: 5
# Class: Ontario - Encoded Value: 6
# Class: Prince Edward Island - Encoded Value: 7
# Class: Quebec - Encoded Value: 8
# Class: Saskatchewan - Encoded Value: 9

# %%
# Accessing the encoded values and their corresponding classes
encoded_classes_soil = le_soil.classes_
print("Encoded Classes:", encoded_classes_soil)

# Printing encoded values for each class
for cls, encoded_value in zip(encoded_classes_soil, range(len(encoded_classes_soil))):
    print(f"Class: {cls} - Encoded Value: {encoded_value}")
# Out:
# Encoded Classes: ['Chernozem' 'Luvisol' 'Podzol']
# Class: Chernozem - Encoded Value: 0
# Class: Luvisol - Encoded Value: 1
# Class: Podzol - Encoded Value: 2

# %%
# Accessing the encoded values and their corresponding classes
encoded_classes_Crop = le_agricultural_practices.classes_
print("Encoded Classes:", encoded_classes_Crop)

# Printing encoded values for each class
for cls, encoded_value in zip(encoded_classes_Crop, range(len(encoded_classes_Crop))):
    print(f"Class: {cls} - Encoded Value: {encoded_value}")
# Out:
# Encoded Classes: ['Dairy farming' 'Fishing' 'Fruit farming' 'Grain farming' 'Mixed farming'
#  'Potato farming']
# Class: Dairy farming - Encoded Value: 0
# Class: Fishing - Encoded Value: 1
# Class: Fruit farming - Encoded Value: 2
# Class: Grain farming - Encoded Value: 3
# Class: Mixed farming - Encoded Value: 4
# Class: Potato farming - Encoded Value: 5

# %%
# Accessing the encoded values and their corresponding classes
encoded_classes_Agricultural_Practices = le_agricultural_practices.classes_
print("Encoded Classes:", encoded_classes_Agricultural_Practices)

# Printing encoded values for each class
for cls, encoded_value in zip(encoded_classes_Agricultural_Practices, range(len(encoded_classes_Agricultural_Practices))):
    print(f"Class: {cls} - Encoded Value: {encoded_value}")
# Out:
# Encoded Classes: ['Dairy farming' 'Fishing' 'Fruit farming' 'Grain farming' 'Mixed farming'
#  'Potato farming']
# Class: Dairy farming - Encoded Value: 0
# Class: Fishing - Encoded Value: 1
# Class: Fruit farming - Encoded Value: 2
# Class: Grain farming - Encoded Value: 3
# Class: Mixed farming - Encoded Value: 4
# Class: Potato farming - Encoded Value: 5

# %%
X = df[['Region', 'Soil_Type', 'Agricultural_Practices']]
y = df['Crop']

# %%
# Train a decision tree classifier
dt = DecisionTreeClassifier()
dt.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
def predict_crop(region, soil_type, agricultural_practices):
    # Encode the region, soil_type, and agricultural_practices
    region_encoded = le_region.transform([region])[0]
    soil_type_encoded = le_soil.transform([soil_type])[0]
    agricultural_practices_encoded = le_agricultural_practices.transform([agricultural_practices])[0]
    
    # Predict the crop
    crop_encoded = dt.predict([[region_encoded, soil_type_encoded, agricultural_practices_encoded]])[0]
    
    # Decode the predicted crop
    predicted_crop = le_crop.inverse_transform([crop_encoded])[0]
    
    return predicted_crop

# %%
region = 'Manitoba'
soil_type = 'Podzol'
agricultural_practices = 'Fruit farming'
predicted_crop = predict_crop(region, soil_type, agricultural_practices)
print(f"The predicted crop for region '{region}', soil type '{soil_type}', and agricultural practices '{agricultural_practices}' is: {predicted_crop}")
# Out:
# The predicted crop for region 'Manitoba', soil type 'Podzol', and agricultural practices 'Fruit farming' is: Apples
# /home/baksho/Work/Farm_Tech/farm_tech_env/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
dump(dt, '../saved_model/model.joblib')
# Out:
# ['../saved_model/model.joblib']
